# %%
cd C:\Users\lenovo\Desktop\Divya\lnmiit ml
# Out:
# C:\Users\lenovo\Desktop\Divya\lnmiit ml

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
a=np.loadtxt("data1.txt")

# %%
a
# Out:
# array([[ 0.        ,  1.        ,  2.        , ...,  8.        ,
#          9.        , 10.        ],
#        [ 2.        ,  3.201     ,  5.77470148, ..., -0.08273688,
#         -0.31659793,  8.9705947 ],
#        [ 1.        ,  1.066     ,  0.51969346, ..., -0.05726641,
#          0.12953615,  6.40681803],
#        ...,
#        [ 1.        ,  0.854     ,  0.97744937, ..., -0.14189873,
#          0.35539943,  0.06023684],
#        [ 1.        ,  0.03      ,  0.09371179, ..., -0.13902791,
#          0.49674919,  0.07933982],
#        [ 2.        ,  3.881     ,  5.77286718, ...,  0.84925859,
#         -0.92115962, 17.13040574]])

# %%
label=a[1:,[0]]
label.shape
# Out:
# (999, 1)

# %%
features=a[1:,1:11]
features.shape
# Out:
# (999, 10)

# %%
b=label.reshape(999)

# %%
col=[]
for i in b:
    if i==1:
        col.append("R")
    else:
        col.append("G")

# %%
k=1
for i in range(1,11):
    for j in range(i+1,11):
            plt.xlabel("feature {}".format(i))
            plt.ylabel("feature {}".format(j))
            plt.title("Graph {}".format(k))
            plt.scatter(a[:,i], a[:,j], c=[r for r in col], marker="o")
            plt.show()
            k+=1
